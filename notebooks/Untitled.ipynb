# %%
from kedro.framework.session import KedroSession
from kedro.framework.startup import bootstrap_project
from pathlib import Path

path = Path("C:/Users/pc/repaso_ciencia/repaso-ciencia")
bootstrap_project(path)

with KedroSession.create(project_path=path) as session:
    catalog = session.load_context().catalog
    print(catalog.keys())

# %%
import pandas as pd

df = pd.read_csv("C:/Users/pc/repaso_ciencia/repaso-ciencia/data/01_raw/Housing.csv")
df.head()
